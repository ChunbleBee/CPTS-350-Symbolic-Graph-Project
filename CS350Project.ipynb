# %%
# %load_ext gvmagic
from CS350Project import *

# %%
graphAll = runForAll()

graph = runForUnique(5, 8)

graph2 = runForUnique(23, 8)

graph3 = runForUnique(23, 19)
graph4 = runForUnique(24, 24)
graph4 = runForUnique(24, 23)

# %dotobj graph
# %dotobj graph2
# Out:
# Calculating if, for all Prime Nodes > 2, < 32, they can reach some Even Node in an even number of steps...
#
# Getting all node egdes...
# 	 Node  0  edges: 	 (0, 3) 	 (0, 8)
# 	 Node  1  edges: 	 (1, 4) 	 (1, 9)
# 	 Node  2  edges: 	 (2, 5) 	 (2, 10)
# 	 Node  3  edges: 	 (3, 6) 	 (3, 11)
# 	 Node  4  edges: 	 (4, 7) 	 (4, 12)
# 	 Node  5  edges: 	 (5, 8) 	 (5, 13)
# 	 Node  6  edges: 	 (6, 9) 	 (6, 14)
# 	 Node  7  edges: 	 (7, 10) 	 (7, 15)
# 	 Node  8  edges: 	 (8, 11) 	 (8, 16)
# 	 Node  9  edges: 	 (9, 12) 	 (9, 17)
# 	 Node  10  edges: 	 (10, 13) 	 (10, 18)
# 	 Node  11  edges: 	 (11, 14) 	 (11, 19)
# 	 Node  12  edges: 	 (12, 15) 	 (12, 20)
# 	 Node  13  edges: 	 (13, 16) 	 (13, 21)
# 	 Node  14  edges: 	 (14, 17) 	 (14, 22)
# 	 Node  15  edges: 	 (15, 18) 	 (15, 23)
# 	 Node  16  edges: 	 (16, 19) 	 (16, 24)
# 	 Node  17  edges: 	 (17, 20) 	 (17, 25)
# 	 Node  18  edges: 	 (18, 21) 	 (18, 26)
# 	 Node  19  edges: 	 (19, 22) 	 (19, 27)
# ...
